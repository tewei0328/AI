# %% [markdown]
# <a href="https://colab.research.google.com/github/tewei0328/AI/blob/master/%E5%96%AE%E5%85%831/01-2.%20MARKDOWN_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 第一章 Colab
#
# <img height="60px" src="/img/colab_favicon.ico" align="left" hspace="20px" vspace="5px">
#
# ## 歡迎使用 Colaboratory！
#
# Colaboratory
# 是免費的Jupyter筆記本環境，不需要進行任何設置就可以使用，並且完全在雲端運行。
#
# ## 功能簡介
#
# - [1.貼python程式碼](#scrollTo=MKgJXe1UG1lG)
# - [2.貼文字](#scrollTo=xYNcT4mVOlen)
# - [3.貼照片](#scrollTo=4IF2JBMT46pC)
# - [4.貼YouTube影片](#scrollTo=6_wR1G9GLJ3H)
# - [5.貼mp3聲音檔](#scrollTo=6mUkqeoFFxSf)
# - [6.用pandas套件載入資料]

# %% [markdown]
# #1.貼python程式碼

# %%
print(1+1)
# Out:
# 2

# %% [markdown]
# #2.貼文字
# ## 使用入門
#
# - [表单](/notebooks/forms.ipynb)、[图表](/notebooks/charts.ipynb)、[Markdown](/notebooks/markdown_guide.ipynb) 以及[微件](/notebooks/widgets.ipynb)
# - [使用 Google Cloud BigQuery](/notebooks/bigquery.ipynb)
# - [机器学习速成课程](https://developers.google.com/machine-learning/crash-course/)：[Pandas 简介](/notebooks/mlcc/intro_to_pandas.ipynb)以及[使用 TensorFlow 的起始步骤](/notebooks/mlcc/first_steps_with_tensor_flow.ipynb)

# %% [markdown]
# # 3.貼照片
#
#
# *   一般帳戶之google drive上存放的照片才可(G Suite不可)
# *   jpg, png均可
# *   open要改成uc
# *   到wikimedia找不用下載的線上照片
# *   用html的img
#
# ![替代文字](https://drive.google.com/uc?id=11FiE84wLhAcwMh6OYSScF0PLKtEQEmBX)

# %% [markdown]
# ![Google's logo](https://www.google.com/images/logos/google_logo_41.png)

# %% [markdown]
# ![替代文字](https://drive.google.com/uc?id=0B7ktfXOBejEGb2NWV285aDl6RDA)

# %% [markdown]
# ![替代文字](https://upload.wikimedia.org/wikipedia/commons/d/d9/Larry_Ellison_on_stage.jpg)

# %% [markdown]
# <img height="60px" src="/img/colab_favicon.ico" align="left" hspace="20px" vspace="5px">

# %% [markdown]
# <img height="200px" src="https://upload.wikimedia.org/wikipedia/commons/d/d9/Larry_Ellison_on_stage.jpg" align="left" hspace="20px" vspace="5px">

# %% [markdown]
# #4.貼YouTube影片

# %%
#@title Colaboratory 简介 { display-mode: "form" }
#@markdown 下面这个时长 3 分钟的视频概述了 Colaboratory 的主要功能：
from IPython.display import YouTubeVideo
YouTubeVideo('inN8seMm7UI', width=600, height=400)

# %% [markdown]
# # 5.貼mp3聲音檔

# %%
# !pip install gTTS
from gtts import gTTS
tts = gTTS(text='馬斯好棒棒快訂閱', lang='zh-tw')
tts.save('hello.mp3')

import IPython
IPython.display.Audio("hello.mp3", autoplay=True)
# Out:
# Requirement already satisfied: gTTS in /usr/local/lib/python3.6/dist-packages (2.0.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from gTTS) (4.6.3)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from gTTS) (1.12.0)
# Requirement already satisfied: gtts-token>=1.1.3 in /usr/local/lib/python3.6/dist-packages (from gTTS) (1.1.3)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from gTTS) (7.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from gTTS) (2.21.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->gTTS) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->gTTS) (2019.6.16)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->gTTS) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->gTTS) (1.24.3)
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import IPython
IPython.display.Audio("drive/My Drive/Colab Notebooks/mp3/voice1.mp3", autoplay=True)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
IPython.display.Audio("voice1.mp3", autoplay=True)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# http://www1.chihlee.edu.tw/teachers/ctw/mp3/colab2.mp3

# %%
import IPython
IPython.display.Audio("http://www1.chihlee.edu.tw/teachers/ctw/mp3/colab2.mp3", autoplay=True)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # 6.用pandas套件載入資料
# ##（第一級）載入colab內已存在之測試資料

# %%
import pandas as pd

# %%
df=pd.read_csv("./sample_data/california_housing_train.csv")

# %%
df.head()
# Out:
#    longitude  latitude  ...  median_income  median_house_value
# 0    -114.31     34.19  ...         1.4936             66900.0
# 1    -114.47     34.40  ...         1.8200             80100.0
# 2    -114.56     33.69  ...         1.6509             85700.0
# 3    -114.57     33.64  ...         3.1917             73400.0
# 4    -114.57     33.57  ...         1.9250             65500.0
#
# [5 rows x 9 columns]
