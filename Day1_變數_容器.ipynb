# %% [markdown]
# <a href="https://colab.research.google.com/github/tewei0328/AI/blob/master/Day1_%E8%AE%8A%E6%95%B8_%E5%AE%B9%E5%99%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.底層, 原子: 字串str, 整數int, 小數float, 布林bool

# %%
aaa='hello'

# %%
type(aaa)
# Out:
# str

# %%
rooms = {1: 'Foyer', 2: 'Conference Room'}
room = input('Enter the room number: ')
if not room in rooms:
	print('Room does not exist.')
else:
	print("The room name is " + rooms[room])
# Out:
# Enter the room number: 1
# Room does not exist.

# %%
type(room)
# Out:
# str

# %%
room
# Out:
# '1'

# %%
rooms = {1: 'Foyer', 2: 'Conference Room'}
room = int(input('Enter the room number: '))
if not room in rooms:
	print('Room does not exist.')
else:
	print("The room name is " + rooms[room])
# Out:
# Enter the room number: 1
# The room name is Foyer
