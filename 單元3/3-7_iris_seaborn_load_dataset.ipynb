# %% [markdown]
# <a href="https://colab.research.google.com/github/tewei0328/AI/blob/master/%E5%96%AE%E5%85%833/3-7_iris_seaborn_load_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 機器學習的起點: 鳶尾花 Iris Dataset
# ![梵谷](https://drive.google.com/uc?id=1g7E-YOF--CxgRcSB6a9cq0G3qlOeFKrT)
# 鳶尾花 (梵谷)
#
#
# ![替代文字](https://drive.google.com/uc?id=19cQN_ZJb_6RgexoYqTTrUtBSPBvUsC6R)
#
# * Patal 花瓣
# * Sepal 花萼
#
# ![替代文字](https://drive.google.com/uc?id=1FYGLsdxT7fSB6Yv138bdQemzJp4IoDsF)
#
# ![替代文字](https://drive.google.com/uc?id=17BRmHl2Bd9PNOqBl_qV9ul_lJ1nKDV3V)
#
# ![替代文字](https://drive.google.com/uc?id=1GXjzzG1xHWbspvg-J4d1RM_Jp2ECJ4vw)
#
# ![替代文字](https://drive.google.com/uc?id=1w7Q-FXCgcgx_orLrQZ2qEkjijqX3iRa2)

# %% [markdown]
# #Colab貼圖法
# *   一般帳戶之google drive上存放的照片才可(G Suite不可)
# *   jpg, png均可
# *   若使用google drive上存放的照片, 在分享連結後, 連結網址上的open要改成uc
# *   到wikimedia找不用下載的線上照片
# *   用html的img

# %%
import seaborn as sb
iris=sb.load_dataset('iris')
iris.head(50)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
# %matplotlib inline
sb.set()
sb.pairplot(iris, hue='species', height=2)

# %%
import seaborn as sb
iris=sb.load_dataset('iris')
iris.head()

# %matplotlib inline
sb.set()
sb.pairplot(iris, hue='species', height=1.5)

X_iris=iris.drop('species', axis=1)
X_iris.shape
y_iris=iris['species']
y_iris.shape
# Out:
# (150,)

# %% [markdown]
# #iris-ML-VIS-kaggle-pandas-seaborn-plotly
# https://www.kaggle.com/xuhewen/iris-dataset-visualization-and-machine-learning
