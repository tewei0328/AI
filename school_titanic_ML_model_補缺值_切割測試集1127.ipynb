# %% [markdown]
# <a href="https://colab.research.google.com/github/tewei0328/AI/blob/master/school_titanic_ML_model_%E8%A3%9C%E7%BC%BA%E5%80%BC_%E5%88%87%E5%89%B2%E6%B8%AC%E8%A9%A6%E9%9B%861127.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.取得鐵達尼號完整資料集

# %%
import pandas as pd

# %%
titanic=pd.read_csv('https://raw.githubusercontent.com/tewei0328/data/master/titanic.csv')

# %%
titanic.shape
# Out:
# (1313, 11)

# %%
titanic.head()
# Out:
#    row.names pclass  survived  ...      ticket   boat     sex
# 0          1    1st         1  ...  24160 L221      2  female
# 1          2    1st         0  ...         NaN    NaN  female
# 2          3    1st         0  ...         NaN  (135)    male
# 3          4    1st         0  ...         NaN    NaN  female
# 4          5    1st         1  ...         NaN     11    male
#
# [5 rows x 11 columns]

# %% [markdown]
# # 2.將資料切片成題目X, 和答案y
# 並進一步切割成訓練集, 和測試集

# %%
X=titanic[['pclass','age','sex']]

# %%
X.head()
# Out:
#   pclass      age     sex
# 0    1st  29.0000  female
# 1    1st   2.0000  female
# 2    1st  30.0000    male
# 3    1st  25.0000  female
# 4    1st   0.9167    male

# %%
y=titanic[['survived']]

# %%
y.head()
# Out:
#    survived
# 0         1
# 1         0
# 2         0
# 3         0
# 4         1

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1313 entries, 0 to 1312
# Data columns (total 3 columns):
# pclass    1313 non-null object
# age       633 non-null float64
# sex       1313 non-null object
# dtypes: float64(1), object(2)
# memory usage: 30.9+ KB

# %% [markdown]
# # 3.補缺值

# %%
X['age'].fillna(X['age'].mean(),inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:6287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1313 entries, 0 to 1312
# Data columns (total 3 columns):
# pclass    1313 non-null object
# age       1313 non-null float64
# sex       1313 non-null object
# dtypes: float64(1), object(2)
# memory usage: 30.9+ KB

# %%
X.describe()
# Out:
#                age
# count  1313.000000
# mean     31.194181
# std      10.235540
# min       0.166700
# 25%      30.000000
# 50%      31.194181
# 75%      31.194181
# max      71.000000

# %%
X.head()
# Out:
#   pclass      age     sex
# 0    1st  29.0000  female
# 1    1st   2.0000  female
# 2    1st  30.0000    male
# 3    1st  25.0000  female
# 4    1st   0.9167    male

# %% [markdown]
# # 4. 將資料進一步切割成訓練集, 和測試集

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.25, random_state=33)

# %%
X_train.head()
# Out:
#      pclass        age     sex
# 1086    3rd  31.194181    male
# 12      1st  31.194181  female
# 1036    3rd  31.194181    male
# 833     3rd  32.000000    male
# 1108    3rd  31.194181    male

# %%
X_train.shape
# Out:
# (984, 3)

# %%
X_test.shape
# Out:
# (329, 3)

# %% [markdown]
# # 5. 取特徵

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
vec=DictVectorizer(sparse=False)

# %%
X_train1=vec.fit_transform(X_train.to_dict(orient='record'))

# %%
X_train1
# Out:
# array([[31.19418104,  0.        ,  0.        ,  1.        ,  0.        ,
#          1.        ],
#        [31.19418104,  1.        ,  0.        ,  0.        ,  1.        ,
#          0.        ],
#        [31.19418104,  0.        ,  0.        ,  1.        ,  0.        ,
#          1.        ],
#        ...,
#        [12.        ,  0.        ,  1.        ,  0.        ,  1.        ,
#          0.        ],
#        [18.        ,  0.        ,  1.        ,  0.        ,  0.        ,
#          1.        ],
#        [31.19418104,  0.        ,  0.        ,  1.        ,  1.        ,
#          0.        ]])

# %%
print(vec.feature_names_)
# Out:
# ['age', 'pclass=1st', 'pclass=2nd', 'pclass=3rd', 'sex=female', 'sex=male']

# %%
print(vec.get_feature_names())
# Out:
# ['age', 'pclass=1st', 'pclass=2nd', 'pclass=3rd', 'sex=female', 'sex=male']
